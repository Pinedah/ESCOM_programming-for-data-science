# %% [markdown]
# # uso de dataset

# %%
import pandas as pd

# %%
dataset = 'spotify.csv'
df = pd.read_csv(dataset)

# %%
df
# Out:
#                               track_name      artist(s)_name  artist_count  \
# 0    Seven (feat. Latto) (Explicit Ver.)    Latto, Jung Kook             2
# 1                                   LALA         Myke Towers             1
# 2                                vampire      Olivia Rodrigo             1
# 3                           Cruel Summer        Taylor Swift             1
# 4                         WHERE SHE GOES           Bad Bunny             1
# ..                                   ...                 ...           ...
# 948                         My Mind & Me        Selena Gomez             1
# 949            Bigger Than The Whole Sky        Taylor Swift             1
# 950                 A Veces (feat. Feid)  Feid, Paulo Londra             2
# 951                        En La De Ella  Feid, Sech, Jhayco             3
# 952                                Alone           Burna Boy             1
#
# ...

# %%
df.shape
# Out:
# (953, 25)

# %%
df.head()
# Out:
#                             track_name    artist(s)_name  artist_count  \
# 0  Seven (feat. Latto) (Explicit Ver.)  Latto, Jung Kook             2
# 1                                 LALA       Myke Towers             1
# 2                              vampire    Olivia Rodrigo             1
# 3                         Cruel Summer      Taylor Swift             1
# 4                       WHERE SHE GOES         Bad Bunny             1
#
#    released_year  released_month  released_day  in_spotify_playlists  \
# 0           2023               7            14                   553
# 1           2023               3            23                  1474
# 2           2023               6            30                  1397
# 3           2019               8            23                  7858
# 4           2023               5            18                  3133
#
#    in_spotify_charts    streams  in_apple_playlists  ...  key   mode  \
# ...

# %%
df.columns
# Out:
# Index(['track_name', 'artist(s)_name', 'artist_count', 'released_year',
#        'released_month', 'released_day', 'in_spotify_playlists',
#        'in_spotify_charts', 'streams', 'in_apple_playlists', 'in_apple_charts',
#        'in_deezer_playlists', 'in_deezer_charts', 'in_shazam_charts', 'bpm',
#        'key', 'mode', 'danceability_%', 'valence_%', 'energy_%',
#        'acousticness_%', 'instrumentalness_%', 'liveness_%', 'speechiness_%',
#        'cover_url'],
#       dtype='object')

# %%
df.tail()
# Out:
#                     track_name      artist(s)_name  artist_count  \
# 948               My Mind & Me        Selena Gomez             1
# 949  Bigger Than The Whole Sky        Taylor Swift             1
# 950       A Veces (feat. Feid)  Feid, Paulo Londra             2
# 951              En La De Ella  Feid, Sech, Jhayco             3
# 952                      Alone           Burna Boy             1
#
#      released_year  released_month  released_day  in_spotify_playlists  \
# 948           2022              11             3                   953
# 949           2022              10            21                  1180
# 950           2022              11             3                   573
# 951           2022              10            20                  1320
# 952           2022              11             4                   782
#
#      in_spotify_charts    streams  in_apple_playlists  ...  key   mode  \
# 948                  0   91473363                  61  ...    A  Major
# ...

# %%
df_ = pd.read_csv(dataset, index_col=0)
df_
# Out:
#                                          artist(s)_name  artist_count  \
# track_name
# Seven (feat. Latto) (Explicit Ver.)    Latto, Jung Kook             2
# LALA                                        Myke Towers             1
# vampire                                  Olivia Rodrigo             1
# Cruel Summer                               Taylor Swift             1
# WHERE SHE GOES                                Bad Bunny             1
# ...                                                 ...           ...
# My Mind & Me                               Selena Gomez             1
# Bigger Than The Whole Sky                  Taylor Swift             1
# A Veces (feat. Feid)                 Feid, Paulo Londra             2
# En La De Ella                        Feid, Sech, Jhayco             3
# Alone                                         Burna Boy             1
#
#                                      released_year  released_month  \
# track_name
# ...

# %%
df.head(0), df_.head(0)
# Out:
# (Empty DataFrame
#  Columns: [track_name, artist(s)_name, artist_count, released_year, released_month, released_day, in_spotify_playlists, in_spotify_charts, streams, in_apple_playlists, in_apple_charts, in_deezer_playlists, in_deezer_charts, in_shazam_charts, bpm, key, mode, danceability_%, valence_%, energy_%, acousticness_%, instrumentalness_%, liveness_%, speechiness_%, cover_url]
#  Index: []
#
#  [0 rows x 25 columns],
#  Empty DataFrame
#  Columns: [artist(s)_name, artist_count, released_year, released_month, released_day, in_spotify_playlists, in_spotify_charts, streams, in_apple_playlists, in_apple_charts, in_deezer_playlists, in_deezer_charts, in_shazam_charts, bpm, key, mode, danceability_%, valence_%, energy_%, acousticness_%, instrumentalness_%, liveness_%, speechiness_%, cover_url]
#  Index: []
#
#  [0 rows x 24 columns])

# %%
col1 = df['track_name']
col1
# Out:
# 0      Seven (feat. Latto) (Explicit Ver.)
# 1                                     LALA
# 2                                  vampire
# 3                             Cruel Summer
# 4                           WHERE SHE GOES
#                       ...
# 948                           My Mind & Me
# 949              Bigger Than The Whole Sky
# 950                   A Veces (feat. Feid)
# 951                          En La De Ella
# 952                                  Alone
# Name: track_name, Length: 953, dtype: object

# %%
col1.to_csv('nombres.csv')

# %%
col11 = pd.read_csv('nombres.csv')
col11
# Out:
#      Unnamed: 0                           track_name
# 0             0  Seven (feat. Latto) (Explicit Ver.)
# 1             1                                 LALA
# 2             2                              vampire
# 3             3                         Cruel Summer
# 4             4                       WHERE SHE GOES
# ..          ...                                  ...
# 948         948                         My Mind & Me
# 949         949            Bigger Than The Whole Sky
# 950         950                 A Veces (feat. Feid)
# 951         951                        En La De Ella
# 952         952                                Alone
#
# [953 rows x 2 columns]

# %%
df.artist(\s)\_name # se muere debido al nombre de la columna
# Out:
#   Cell In[26], line 1
#     df.artist(\s)\_name # se muere debido al nombre de la columna
#                ^
# SyntaxError: unexpected character after line continuation character

# %%
df['artist(s)_name'] # lo propio
# Out:
# 0        Latto, Jung Kook
# 1             Myke Towers
# 2          Olivia Rodrigo
# 3            Taylor Swift
# 4               Bad Bunny
#               ...
# 948          Selena Gomez
# 949          Taylor Swift
# 950    Feid, Paulo Londra
# 951    Feid, Sech, Jhayco
# 952             Burna Boy
# Name: artist(s)_name, Length: 953, dtype: object

# %%
df[['track_name', 'artist(s)_name']] # regresa todas
# Out:
#                               track_name      artist(s)_name
# 0    Seven (feat. Latto) (Explicit Ver.)    Latto, Jung Kook
# 1                                   LALA         Myke Towers
# 2                                vampire      Olivia Rodrigo
# 3                           Cruel Summer        Taylor Swift
# 4                         WHERE SHE GOES           Bad Bunny
# ..                                   ...                 ...
# 948                         My Mind & Me        Selena Gomez
# 949            Bigger Than The Whole Sky        Taylor Swift
# 950                 A Veces (feat. Feid)  Feid, Paulo Londra
# 951                        En La De Ella  Feid, Sech, Jhayco
# 952                                Alone           Burna Boy
#
# [953 rows x 2 columns]

# %%
df[['track_name', 'artist(s)_name']][2] # se muere pq ocupa que se use iloc
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Dell Latitude\Documents\GitHub\programming-for-data-science\.venv\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 2
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[39], line 1
# ...

# %%
df.iloc[2][['track_name', 'artist(s)_name']] # usando ilocGOD
# Out:
# track_name               vampire
# artist(s)_name    Olivia Rodrigo
# Name: 2, dtype: object

# %%
df.iloc[-1] # me regresa la ultima fila
# Out:
# track_name                                                          Alone
# artist(s)_name                                                  Burna Boy
# artist_count                                                            1
# released_year                                                        2022
# released_month                                                         11
# released_day                                                            4
# in_spotify_playlists                                                  782
# in_spotify_charts                                                       2
# streams                                                          96007391
# in_apple_playlists                                                     27
# in_apple_charts                                                        18
# in_deezer_playlists                                                    32
# in_deezer_charts                                                        1
# ...

# %%
df.iloc[:, 1] # regresa todas las filas, de la columna 1
# Out:
# 0        Latto, Jung Kook
# 1             Myke Towers
# 2          Olivia Rodrigo
# 3            Taylor Swift
# 4               Bad Bunny
#               ...
# 948          Selena Gomez
# 949          Taylor Swift
# 950    Feid, Paulo Londra
# 951    Feid, Sech, Jhayco
# 952             Burna Boy
# Name: artist(s)_name, Length: 953, dtype: object

# %%
df.iloc[:, 0:2] # regresa todas las filas de los columnas 0, 1 y 2
# Out:
#                               track_name      artist(s)_name
# 0    Seven (feat. Latto) (Explicit Ver.)    Latto, Jung Kook
# 1                                   LALA         Myke Towers
# 2                                vampire      Olivia Rodrigo
# 3                           Cruel Summer        Taylor Swift
# 4                         WHERE SHE GOES           Bad Bunny
# ..                                   ...                 ...
# 948                         My Mind & Me        Selena Gomez
# 949            Bigger Than The Whole Sky        Taylor Swift
# 950                 A Veces (feat. Feid)  Feid, Paulo Londra
# 951                        En La De Ella  Feid, Sech, Jhayco
# 952                                Alone           Burna Boy
#
# [953 rows x 2 columns]

# %%
df.iloc[:, 0:2]
# Out:
#                               track_name      artist(s)_name
# 0    Seven (feat. Latto) (Explicit Ver.)    Latto, Jung Kook
# 1                                   LALA         Myke Towers
# 2                                vampire      Olivia Rodrigo
# 3                           Cruel Summer        Taylor Swift
# 4                         WHERE SHE GOES           Bad Bunny
# ..                                   ...                 ...
# 948                         My Mind & Me        Selena Gomez
# 949            Bigger Than The Whole Sky        Taylor Swift
# 950                 A Veces (feat. Feid)  Feid, Paulo Londra
# 951                        En La De Ella  Feid, Sech, Jhayco
# 952                                Alone           Burna Boy
#
# [953 rows x 2 columns]

# %%
df.iloc[[1,10], [0,1,2]]
# Out:
#    track_name             artist(s)_name  artist_count
# 1        LALA                Myke Towers             1
# 10  un x100to  Bad Bunny, Grupo Frontera             2

# %%
# mapa
findesemana = (df['artist(s)_name'] == 'The Weeknd') & (df['released_year'] > 2020)

# %%
df.loc[findesemana, 'track_name']
# Out:
# 501                     Sacrifice
# 502        Is There Someone Else?
# 504                   Out of Time
# 508    How Do I Make You Love Me?
# 509                      Gasoline
# 511                Less Than Zero
# 512                Take My Breath
# 515                  Best Friends
# 521                       Dawn FM
# 523                   Starry Eyes
# 538        Donï¿½ï¿½ï¿½t Break My
# 541              A Tale By Quincy
# 552     Every Angel is Terrifying
# 577         Phantom Regret by Jim
# 616                Take My Breath
# Name: track_name, dtype: object

# %%
df.loc[df['artist(s)_name'].isnull()]
# Out:
# Empty DataFrame
# Columns: [track_name, artist(s)_name, artist_count, released_year, released_month, released_day, in_spotify_playlists, in_spotify_charts, streams, in_apple_playlists, in_apple_charts, in_deezer_playlists, in_deezer_charts, in_shazam_charts, bpm, key, mode, danceability_%, valence_%, energy_%, acousticness_%, instrumentalness_%, liveness_%, speechiness_%, cover_url]
# Index: []
#
# [0 rows x 25 columns]

# %%
for c in df.columns:
    print(f"{pd.isnull(df[c]).values.ravel().sum()} - {c}") #contamos cuantos valores son nulos
# Out:
# 0 - track_name
# 0 - artist(s)_name
# 0 - artist_count
# 0 - released_year
# 0 - released_month
# 0 - released_day
# 0 - in_spotify_playlists
# 0 - in_spotify_charts
# 0 - streams
# 0 - in_apple_playlists
# 0 - in_apple_charts
# 0 - in_deezer_playlists
# 0 - in_deezer_charts
# 50 - in_shazam_charts
# 0 - bpm
# 95 - key
# 0 - mode
# 0 - danceability_%
# 0 - valence_%
# 0 - energy_%
# 0 - acousticness_%
# 0 - instrumentalness_%
# 0 - liveness_%
# 0 - speechiness_%
# 0 - cover_url
